# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import pandas as pd
import numpy as np

# %%
url = requests.get("https://megogo.ru/ru/films/main")

# %%
soup = BeautifulSoup(url.text, "html.parser")

# %%
currentElement = soup.findAll('div', attrs={'class':['thumbnail']})
                                                     #card-content video-content'])
                                                     #thumbnail']})
#short clearfix with-mask
#movie = soup.find('h3', {'class': 'video-title'}).text
#movie = soup.find('span', {'class': 'video-year'}).text

#print(currentElement)
#print(movie)

# %%
name_rus = [0] * 250
year = [0] * 250
name_eng = [' '] * 250
rating = [0] * 250
marks_number = [0] * 250
genre = [0] * 250

for i in range(1, 251):
    movie_Current = soup.find('div', attrs={'class':'thumbnail'})
    movie = movie_Current.find('div', attr = {'class':'card-content video-content'})
    #name_rus[i-1] = movie.find('h3', {'class':'video-title'}).text
    name_rus[i-1] = movie.find('h3', {'class':'video-title'}).text
    #year[i-1] = movie.find('div', {'class': 'video-info'})#.text
   # genre[i-1] = movie.find('span',{'class':'video-country'})#.text
        
   # movie_id[i-1] = movie.find('div', {'class': 'item'}).get('id')[movie.find('div', {'class': 'item'}).get('id').rfind('_')+1:]
    #rating[i-1] = movie.find('a', {'class': 'continue'}).text
    #marks_number[i-1] = movie.find('span', {'style': 'color: #777'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-5c6cc48fc9f9> in <module>()
#      10     movie = movie_Current.find('div', attr = {'class':'card-content video-content'})
#      11     #name_rus[i-1] = movie.find('h3', {'class':'video-title'}).text
# ---> 12     name_rus[i-1] = movie.find('a').text
#      13     #year[i-1] = movie.find('div', {'class': 'video-info'})#.text
#      14    # genre[i-1] = movie.find('span',{'class':'video-country'})#.text
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
top250 = pd.DataFrame(index=[i for i in range(1,251)])
top250['Название'] = name_rus
top250['Год выпуска'] = year
top250['Жанр'] = genre

# %%
top250
# Out:
#     Название Год выпуска  Жанр
# 1       None        None  None
# 2       None        None  None
# 3       None        None  None
# 4       None        None  None
# 5       None        None  None
# 6       None        None  None
# 7       None        None  None
# 8       None        None  None
# 9       None        None  None
# 10      None        None  None
# 11      None        None  None
# 12      None        None  None
# 13      None        None  None
# 14      None        None  None
# 15      None        None  None
# 16      None        None  None
# 17      None        None  None
# 18      None        None  None
# 19      None        None  None
# 20      None        None  None
# 21      None        None  None
# 22      None        None  None
# 23      None        None  None
# 24      None        None  None
# 25      None        None  None
# 26      None        None  None
# 27      None        None  None
# 28      None        None  None
# 29      None        None  None
# ...
